# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/eddieloyd/DIS/BigData/final/Big-Data-March-Madness/data/all years.csv")
df = df.rename(columns = {"Tourament-Result": "Tournament-Result"})

# %%
# 1992, 2002, 2012, 2018
# df

# %%
# tournament teams
tournament_teams = df.loc[df["Tournament-Result"] > 0]
# tournament_teams

# %%
non_tournament = df.loc[df["Tournament-Result"] == 0]
# non_tournament

# %%
# W, L, W-L%, SRS, SOS, FG, FGA, Pts-Tm., Pts-Opp., MP,FG,FGA,FG%,3P,3PA,3P%,FT,FTA,FT%,ORB,TRB,AST,STL,BLK,TOV,PF,Pace,ORtg,FTr,3PAr,TS%,TRB%,AST%,STL%,BLK%,eFG%,TOV%,ORB%,FT/FGA

# %%
# 1992 plot
tourny_teams_92 = tournament_teams.loc[tournament_teams["Season"].str.contains("1992-93")]
non_tourny_92 = non_tournament.loc[non_tournament["Season"].str.contains("1992-93")]

#Need to figure out the legend still

# handles, labels = plt.gca().get_legend_handles_labels()
# fig.legend(["Green", "Blue"], ["Non-Tournament", "Tournament"], loc='upper center')

# plt.legend(["Non-tournament", "Tournament"], loc = "upper right")


# axs[0,0].ast_tourny_92.plot.density(color = "green")
# ast_non_92.plot.density(color = "blue")
# plt.title("Assist%")

# %%
fig, axs = plt.subplots(7, 5, figsize = (24, 24))
stats = ["W", "L", "W-L%", "SRS", "SOS", "FG", "FGA", 
             "Pts-Tm.", "Pts-Opp.", "MP","FG","FGA","FG%","3P","3PA","3P%",
             "FT","FTA","FT%","ORB","TRB","AST","STL","BLK","TOV","PF",
             "FTr","3PAr","TS%","TRB%","AST%","BLK%","eFG%","TOV%","FT/FGA"]
plot_x = 0
plot_y = 0
for stat in stats:

    ast_tourny_92 = tourny_teams_92[stat]
    ast_non_92 = non_tourny_92[stat]
    sns.kdeplot(ast_tourny_92, color = "green", ax = axs[plot_x,plot_y])
    sns.kdeplot(ast_non_92, color = "blue", ax = axs[plot_x,plot_y])
    #axs[plot_x, plot_y].set_title(stat)
    
    plot_y += 1
    if plot_y %5 ==0:
        plot_x += 1
        plot_y = 0
    
# Green is Tournament, Blue is non Tournament
# Still need to figure out legend
# Out:
# /var/folders/q9/42jptm7d151_h70_cp05s8dm0000gn/T/ipykernel_16809/3718989260.py:12: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(ast_tourny_92, color = "green", ax = axs[plot_x,plot_y])
# /var/folders/q9/42jptm7d151_h70_cp05s8dm0000gn/T/ipykernel_16809/3718989260.py:13: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(ast_non_92, color = "blue", ax = axs[plot_x,plot_y])

# %%
# 2002 plot
tourny_teams_02 = tournament_teams.loc[tournament_teams["Season"].str.contains("2002-03")]
non_tourny_02 = non_tournament.loc[non_tournament["Season"].str.contains("2002-03")]

# %%
fig, axs = plt.subplots(7, 5, figsize = (24, 24))
stats = ["W", "L", "W-L%", "SRS", "SOS", "FG", "FGA", 
             "Pts-Tm.", "Pts-Opp.", "MP","FG","FGA","FG%","3P","3PA","3P%",
             "FT","FTA","FT%","ORB","TRB","AST","STL","BLK","TOV","PF",
             "FTr","3PAr","TS%","TRB%","AST%","BLK%","eFG%","TOV%","FT/FGA"]
plot_x = 0
plot_y = 0
for stat in stats:

    ast_tourny_02 = tourny_teams_02[stat]
    ast_non_02 = non_tourny_02[stat]
    sns.kdeplot(ast_tourny_02, color = "green", ax = axs[plot_x,plot_y])
    sns.kdeplot(ast_non_02, color = "blue", ax = axs[plot_x,plot_y])
    #axs[plot_x, plot_y].set_title(stat)
    
    plot_y += 1
    if plot_y %5 ==0:
        plot_x += 1
        plot_y = 0
    
# Green is Tournament, Blue is non Tournament
# Still need to figure out legend

# %%
# 2012 plot
tourny_teams_12 = tournament_teams.loc[tournament_teams["Season"].str.contains("2012-13")]
non_tourny_12 = non_tournament.loc[non_tournament["Season"].str.contains("2012-13")]

# %%
fig, axs = plt.subplots(7, 5, figsize = (24, 24))
stats = ["W", "L", "W-L%", "SRS", "SOS", "FG", "FGA", 
             "Pts-Tm.", "Pts-Opp.", "MP","FG","FGA","FG%","3P","3PA","3P%",
             "FT","FTA","FT%","ORB","TRB","AST","STL","BLK","TOV","PF",
             "FTr","3PAr","TS%","TRB%","AST%","BLK%","eFG%","TOV%","FT/FGA"]
plot_x = 0
plot_y = 0
for stat in stats:

    ast_tourny_12 = tourny_teams_12[stat]
    ast_non_12 = non_tourny_12[stat]
    sns.kdeplot(ast_tourny_12, color = "green", ax = axs[plot_x,plot_y])
    sns.kdeplot(ast_non_12, color = "blue", ax = axs[plot_x,plot_y])
    #axs[plot_x, plot_y].set_title(stat)
    
    plot_y += 1
    if plot_y %5 ==0:
        plot_x += 1
        plot_y = 0
    
# Green is Tournament, Blue is non Tournament
# Still need to figure out legend

# %%
# 2016 plot
tourny_teams_16 = tournament_teams.loc[tournament_teams["Season"].str.contains("2016-17")]
non_tourny_16 = non_tournament.loc[non_tournament["Season"].str.contains("2016-17")]

# %%
fig, axs = plt.subplots(7, 5, figsize = (24, 24))
stats = ["W", "L", "W-L%", "SRS", "SOS", "FG", "FGA", 
             "Pts-Tm.", "Pts-Opp.", "MP","FG","FGA","FG%","3P","3PA","3P%",
             "FT","FTA","FT%","ORB","TRB","AST","STL","BLK","TOV","PF",
             "FTr","3PAr","TS%","TRB%","AST%","BLK%","eFG%","TOV%","FT/FGA"]
plot_x = 0
plot_y = 0
for stat in stats:

    ast_tourny_16 = tourny_teams_16[stat]
    ast_non_16 = non_tourny_16[stat]
    sns.kdeplot(ast_tourny_16, color = "green", ax = axs[plot_x,plot_y])
    sns.kdeplot(ast_non_16, color = "blue", ax = axs[plot_x,plot_y])
    #axs[plot_x, plot_y].set_title(stat)
    
    plot_y += 1
    if plot_y %5 ==0:
        plot_x += 1
        plot_y = 0
    
# Green is Tournament, Blue is non Tournament
# Still need to figure out legend

# %%
# School Conference analysis
fig, axs = plt.subplots(2, 2, figsize = (24, 24))

appearances = {}
for conference in tourny_teams_92["Conference"]:
    df_bool = (tourny_teams_92["Conference"] == conference)
    appearances[conference] = sum(df_bool)

conferences = []
amounts = []
for conf in appearances:
    conferences.append(conf)
    amounts.append(appearances[conf])

# 1992 plot
axs[0,0].bar(conferences, amounts)
axs[0,0].set_title("1992")


appearances = {}
for conference in tourny_teams_02["Conference"]:
    df_bool = (tourny_teams_02["Conference"] == conference)
    appearances[conference] = sum(df_bool)

conferences = []
amounts = []
for conf in appearances:
    conferences.append(conf)
    amounts.append(appearances[conf])
    
#02 plot
axs[0,1].bar(conferences, amounts)
axs[0,1].set_title("2002")


appearances = {}
for conference in tourny_teams_12["Conference"]:
    df_bool = (tourny_teams_12["Conference"] == conference)
    appearances[conference] = sum(df_bool)

conferences = []
amounts = []
for conf in appearances:
    conferences.append(conf)
    amounts.append(appearances[conf])
    
#12 plot
axs[1,0].bar(conferences, amounts)
axs[1,0].set_title("2012")



appearances = {}
for conference in tourny_teams_16["Conference"]:
    df_bool = (tourny_teams_16["Conference"] == conference)
    appearances[conference] = sum(df_bool)

conferences = []
amounts = []
for conf in appearances:
    conferences.append(conf)
    amounts.append(appearances[conf])
    
#16 plot
axs[1,1].bar(conferences, amounts)
axs[1,1].set_title("2016")
# Out:
# Text(0.5, 1.0, '2016')

# %%
# Have important stats changed over time
all_stats = {}
#3P, 3PA, 3P%, AST, FG FGA, TOV, BLK
for stat in ["3PAr", "TS%", "3P%", "AST%", "FT%", "TOV%", "BLK%", "TRB%"]:
    tourny_stat = tournament_teams[[stat, "Season"]]
    non_stat = non_tournament[[stat, "Season"]]
    season_tourn_avg = []
    season_non_avg = []
    labels = []
    for i in range(1992, 2017):
        year_2 = str(i + 1)[2:]
        season = "{}-{}".format(i, year_2)
        to_stat = tourny_stat.loc[tourny_stat["Season"].str.contains(season)]
        no_stat = non_stat.loc[non_stat["Season"].str.contains(season)]
        
        to_stat = to_stat[stat]
        no_stat = no_stat[stat]
        
        season_tourn_avg.append(np.mean(to_stat))
        season_non_avg.append(np.mean(no_stat))
        labels.append(season)
    
    
    all_stats[stat] = [labels, season_tourn_avg, season_non_avg]

# %%
i = 0
fig, axs = plt.subplots(8, figsize = (24, 24))

for stat in all_stats:
    axs[i].plot(all_stats[stat][0], all_stats[stat][1])
    axs[i].plot(all_stats[stat][0], all_stats[stat][2])
    axs[i].set_title(stat)
    i+= 1
fig.legend(['Tournament teams', 'Non tournament'], loc='upper left')
